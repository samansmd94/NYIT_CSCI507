# %% [markdown]
# <a href="https://colab.research.google.com/github/samansmd94/NYIT_CSCI507/blob/main/AioLearn_s1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
# Out:
# hello world!

# %%
majid = 10

# %%
print(majid)
# Out:
# 10

# %%
majid = "aiolearn"
print(majid)
# Out:
# aiolearn

# %%
a =10
b = 20
c = a * b
print(c)
# Out:
# 200

# %%
image = cv2.imread("Saman2.jpeg")

image = cv2 .cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
model = cv2.CascadeClassifier("model.xml")

# %%
face = model.detectMultiScale(image)

# %%
print(face)
# Out:
# [[537 552 374 374]
#  [173 836  67  67]]

# %%
image.shape
# Out:
# (1440, 1072, 3)

# %%
image = cv2.rectangle(image, (100,100) , (200,200) , (0,255,0), 3)

# %%
x=face[0][0]
y=face[0][1]
a=face[0][2]
b=face[0][3]

# %%
image = cv2.rectangle(image , (x,y) , (x+a,y+b) , (0,255,0), 3)

# %%
from matplotlib import pyplot as plt
import cv2

# %%
image = cv2.imread("Saman2.jpeg")
model = cv2.CascadeClassifier("model.xml")

face = model.detectMultiScale(image)

x=face[0][0]
y=face[0][1]
a=face[0][2]
b=face[0][3]

image = cv2.rectangle(image , (x,y) , (x+a,y+b) , (0,255,0) , 4)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
